# %%
import pandas as pd
import pymongo
import os
import sys

sys.path.append(r'D:\Code\ML OPS\Insurence-system\src')

from constants import DB_CONNECTION_URL, DB_NAME, DB_COLLECTION_NAME

df = pd.read_csv('data/data.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 3
#       1 import pandas as pd
#       2 import pymongo
# ----> 3 from src.constants import DB_CONNECTION_URL, DB_NAME, DB_COLLECTION_NAME
#       4 df = pd.read_csv('data/data.csv')
#       5 df.head()
#
# ModuleNotFoundError: No module named 'src'

# %%
data = df.to_dict(orient='records')

# %%
client = pymongo.MongoClient(DB_CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[DB_COLLECTION_NAME]

# %%
rec = collection.insert_many(data)
